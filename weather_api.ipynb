# %%
baseurl =  'http://api.weatherapi.com/v1'
byambaa_key = '1bfc0b45eadd4d4f82b21640252812'

# %%
# http://api.weatherapi.com/v1/current.json?key=<YOUR_API_KEY>&q=London

# %%
import requests
import pandas as pd

# %%
city = 'Louisville'
baseurl = f'http://api.weatherapi.com/v1/current.json?key={byambaa_key}&q={city}'
response = requests.get(baseurl)

# %%
response.status_code
# Out:
# 200

# %%
data = response.json()
data
# Out:
# {'location': {'name': 'Louisville',
#   'region': 'Kentucky',
#   'country': 'United States of America',
#   'lat': 38.2542,
#   'lon': -85.7594,
#   'tz_id': 'America/Kentucky/Louisville',
#   'localtime_epoch': 1766892244,
#   'localtime': '2025-12-27 22:24'},
#  'current': {'last_updated_epoch': 1766891700,
#   'last_updated': '2025-12-27 22:15',
#   'temp_c': 15.6,
#   'temp_f': 60.1,
#   'is_day': 0,
#   'condition': {'text': 'Overcast',
#    'icon': '//cdn.weatherapi.com/weather/64x64/night/122.png',
#    'code': 1009},
#   'wind_mph': 4.7,
#   'wind_kph': 7.6,
#   'wind_degree': 141,
#   'wind_dir': 'SE',
#   'pressure_mb': 1013.0,
#   'pressure_in': 29.92,
#   'precip_mm': 0.0,
#   'precip_in': 0.0,
#   'humidity': 80,
#   'cloud': 100,
#   'feelslike_c': 15.6,
#   'feelslike_f': 60.1,
#   'windchill_c': 16.3,
#   'windchill_f': 61.4,
#   'heatindex_c': 16.3,
#   'heatindex_f': 61.4,
#   'dewpoint_c': 14.9,
#   'dewpoint_f': 58.9,
#   'vis_km': 16.0,
#   'vis_miles': 9.0,
# ...

# %%
current = data['current']
location = data['location']
temp_f = current['temp_f']
wind_mph = current['wind_mph']
humidity = current['humidity']

# %%
temp_f , humidity
# Out:
# (60.1, 80)

# %%
def get_weather(city):
    url = baseurl = f'http://api.weatherapi.com/v1/current.json?key={byambaa_key}&q={city}'
    response = requests.get(url)
    if response.status_code == 200:
        data = response.json()
        current = data['current']
        location = data['location']
        temp_f = current['temp_f']
        wind_mph = current['wind_mph']
        humidity = current['humidity']

        print(f'Weather: {location ['name']}, {location['region']}')
        print(f'Temperature:{current['temp_f']} Fh / {current['temp_c']} C')
        print(f'Condition:{current['condition']['text']}')
        print(f'Humidity:{current['humidity']} %')
        print(f'Wind Speed:{current['wind_mph']} mph')

    else:
        print(f'Error Fetching Data for {city}: {response.status_code}')

# %%
get_weather('Easton')
# Out:
# Weather: Easton, Pennsylvania
# Temperature:24.1 Fh / -4.4 C
# Condition:Clear
# Humidity:88 %
# Wind Speed:2.2 mph

# %%
get_weather('Ulaanbaatar')
# Out:
# Weather: Ulaanbaatar, Ulaanbaatar
# Temperature:2.1 Fh / -16.6 C
# Condition:Partly cloudy
# Humidity:77 %
# Wind Speed:2.2 mph
